# %%
import pandas as pd

dados = [
    [1, "Notebook", "Eletrônicos", 3500, 10, "2026-01-15"],
    [2, "Mouse", "Eletrônicos", 80, 50, "2026-01-16"],
    [3, "Teclado", "Eletrônicos", 150, 40, "2026-01-17"],
    [4, "Monitor", "Eletrônicos", 1200, 15, "2026-01-18"],
    [5, "Cadeira", "Móveis", 900, 8, "2026-01-19"],
    [6, "Mesa", "Móveis", 700, 5, "2026-01-20"],
    [7, "Celular", "Eletrônicos", 2500, 20, "2026-01-21"],
    [8, "Fone", "Eletrônicos", 200, 35, "2026-01-22"],
    [9, "Impressora", "Eletrônicos", 650, 7, "2026-01-23"],
    [10, "Luminária", "Casa", 120, 25, "2026-01-24"],
    [11, "Ventilador", "Casa", 300, 12, "2026-01-25"],
    [12, "Sofá", "Móveis", 2200, 3, "2026-01-26"],
    [13, "Tablet", "Eletrônicos", 1800, 9, "2026-01-27"],
    [14, "Carregador", "Eletrônicos", 90, 60, "2026-01-28"],
    [15, "HD Externo", "Eletrônicos", 450, 14, "2026-01-29"]
]

tabela = pd.DataFrame(dados)
print(tabela)

# %% [markdown]
# As colunas sairam erradas pois por padrão do DataFrame pega o primiero elemento e transforma no nome da coluna.

# %%
tabela = pd.DataFrame(
    dados, columns=[
        "id",
        "produto",
        "tipo/categoria",
        "preço",
        "estoque",
        "data_entrada"
        ]
    )
print(tabela)
